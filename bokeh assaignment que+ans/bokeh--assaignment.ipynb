# %%
# 1...
from bokeh.plotting import figure, output_file, show

# Prepare the output file
output_file("my_plot.html")

# Create a new plot with title and axis labels
p = figure(title="My First Bokeh Plot", x_axis_label='x', y_axis_label='y')

# Add a line renderer with a specific color and line width
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="Line", line_width=2, color="blue")

# Add a circle renderer with specific size and color
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=10, color="red", legend_label="Circles")

# Show the results
show(p)

# %%
#2...
from bokeh.plotting import figure, output_file, show

# Prepare the output file
output_file("glyphs_example.html")

# Create a new plot
p = figure(title="Glyphs Example", x_axis_label='x', y_axis_label='y')

# Add a line glyph
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="Line", line_width=2, color="blue")

# Add a circle glyph
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=10, color="red", legend_label="Circles")

# Add a square glyph
p.square([1, 2, 3, 4, 5], [5, 6, 1, 4, 6], size=10, color="green", legend_label="Squares")

# Add a triangle glyph
p.triangle([1, 2, 3, 4, 5], [7, 2, 4, 6, 3], size=10, color="orange", legend_label="Triangles")

# Show the results
show(p)

# %%
#3...
from bokeh.plotting import figure, output_file, show

# Prepare the output file
output_file("glyphs_example.html")

# Create a new plot
p = figure(title="Glyphs Example", x_axis_label='x', y_axis_label='y')

# Add a line glyph
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="Line", line_width=2, color="blue")

# Add a circle glyph
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=10, color="red", legend_label="Circles")

# Add a square glyph
p.square([1, 2, 3, 4, 5], [5, 6, 1, 4, 6], size=10, color="green", legend_label="Squares")

# Add a triangle glyph
p.triangle([1, 2, 3, 4, 5], [7, 2, 4, 6, 3], size=10, color="orange", legend_label="Triangles")

# Show the results
show(p)

# %%
#4...
from bokeh.io import curdoc
from bokeh.layouts import column
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.models.widgets import Slider

# Create a ColumnDataSource to hold plot data
source = ColumnDataSource(data=dict(x=[], y=[]))

# Create a figure
plot = figure(title="Interactive Bokeh Plot", x_axis_label='x', y_axis_label='y')
plot.line(x='x', y='y', source=source)

# Define a callback function for the slider
def update(attr, old, new):
    # Update data based on slider value
    scale = slider.value
    new_x = list(range(10))
    new_y = [scale * x for x in new_x]
    source.data = dict(x=new_x, y=new_y)

# Create a slider widget
slider = Slider(start=1, end=10, value=1, step=0.1, title="Scale")
slider.on_change('value', update)

# Arrange plots and widgets in a layout
layout = column(slider, plot)

# Add the layout to the current document
curdoc().add_root(layout)
